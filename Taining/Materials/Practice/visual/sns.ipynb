# %%
import seaborn as sns
import pandas as pd

df = sns.load_dataset('penguins')
df.to_csv('../data/penguins.csv') 
df.head()

# %%
# df.info()
c=df['flipper_length_mm'].value_counts().reset_index()
c.columns = ['flipper_length_mm','count']   
c

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = sns.load_dataset("penguins")

# Histogram of bill lengths
sns.histplot(data=data, x="bill_length_mm", bins=10,kde=True)
plt.show()
