# %%
r = 5.1
k = 'ravi'
print(type(r))
type(k)
str(r)
# Out:
# <class 'float'>
# '5.1'

# %%
devide = int(input())
devide = devide%2
print (devide)
# print(type(int(devide)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 devide = int(input())
#       2 devide = devide%2
#       3 print (devide)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
l = "ravibalan"
for i in range(1,8):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
i = input()
print(i)
# Out:
# e

# %%
new = list([1,2,3,[3]])
print(type(new))
print(new)
# Out:
# <class 'list'>
# [1, 2, 3, [3]]

# %%
list = ([444],[3]),[3,['w']]
print(type(list[1][0]))
# Out:
# <class 'int'>

# %%
type1 = {"32":'33',33:33, 1:12}
for i in type1:
    print(f"{i}")

print(type(type1))
# Out:
# 32
# 33
# 1
# <class 'dict'>

# %%
type2 = ("Apple","Apple")
print(type(type2))
# Out:
# <class 'tuple'>

# %%
tuple_with_dict=({"key1": "value1", "key2": "value2"}, 2, 3.0)
print(type(tuple_with_dict))
# Out:
# <class 'tuple'>

# %%
#MAP

num = [{"name": "ravi","city":"tuty"},{"name": "ravi","city":"tuty"}]

# %%
import os
dir = r'D:\Alita\DMS\2.0\BPAY_Release\Script\Template Script\1.KS-KTA-TemplateFieldInsertScript.sql'
split = dir.rsplit('\\',maxsplit=1)
print(split[-1])

print(os.path.join(dir,split[-1]))
# Out:
# 1.KS-KTA-TemplateFieldInsertScript.sql
# D:\Alita\DMS\2.0\BPAY_Release\Script\Template Script\1.KS-KTA-TemplateFieldInsertScript.sql\1.KS-KTA-TemplateFieldInsertScript.sql

# %%
list1 = ['dd','ddd']
list1= type(list(list1))
for l in list1:
    print(type(l))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[83], line 2
#       1 list1 = ['dd','ddd']
# ----> 2 list1= type(list(list1))
#       3 for l in list1:
#       4     print(type(l))
#
# TypeError: 'list' object is not callable

# %%
import glob
import os
import shutil

file_directory = r'D:\Alita\DMS\2.0\BPAY_Release\Script\Template Script - Copy\\'
new_file_directory = r'D:\Alita\DMS\2.0\BPAY_Release\Script\Template Script - Copy\New'

pattern = '*.*'  # Matches all files

full_pattern = f'{file_directory}\\{pattern}'
files = glob.glob(full_pattern)
print(len(files))

for file in files:
    file1 = file.rsplit('\\',maxsplit=1)
    new_dir = os.path.join(new_file_directory,file1[-1])
    shutil.copy(file,new_dir)

    with open(new_dir,mode='r') as new_file:
        new_file.write("Creadted By Ravi")
        print("\nSuccessFully Created")




    with open(new_dir,mode='w') as new_file:
        new_file.write("Creadted By Ravi")
        print("\nSuccessFully Created")
# Out:
# 1
#
# SuccessFully Created

# %%
# Import required modules
from abc import ABC, abstractmethod

# Create Abstract base class
class Car(ABC):
    def __init__(self, brand, model, year):
        self.brand = brand
        self.model = model
        self.year = year
    
    # Create abstract method      
    @abstractmethod
    def printDetails(self):
        pass
  
    # Create concrete method
    def accelerate(self):
        print("Speed up ...")
  
    @abstractmethod
    def break_applied(self):
        print("Car stopped")
        pass

# Create a child class
class Hatchback(Car):
    def printDetails(self):
        print("Brand:", self.brand)
        print("Model:", self.model)
        print("Year:", self.year)
  
    def sunroof(self):
        print("Not having this feature")

    def break_applied(self):
        print("Car stopped1")

# Create a child class
class Suv(Car):
    def printDetails(self):
        print("Brand:", self.brand)
        print("Model:", self.model)
        print("Year:", self.year)
  
    def sunroof(self):
        print("Available")

# Create an instance of the Hatchback class
car1 = Hatchback("Maruti", "Alto", "2022")

# Call methods
car1.printDetails()
car1.accelerate()
car1.break_applied()
car1.sunroof()
# Out:
# Brand: Maruti
# Model: Alto
# Year: 2022
# Speed up ...
# Car stopped1
# Not having this feature

# %%
import pandas as pd

df = pd.read_csv('DMS-NTC-TRANS-20241408090950.csv')
# df.head(5)
# df.describe()
df.columns
df.to_numpy()
df.to_json()
df.head(10)
df['TransID'][5:10]

df.at[0,'TransID']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File e:\POWER\DS\Materials\Practice\venv\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 12
#       9 df.head(10)
#      10 df['TransID'][5:10]
# ...

# %%
df = pd.DataFrame({'A':[1,2,3]})
print(df)
# Out:
#    A
# 0  1
# 1  2
# 2  3

# %%
from db import sqlDatabase
import pandas as pd
from sqlalchemy import text


db = sqlDatabase()

d_bill = 'SELECT top 100 * FROM DocumentBill'
d_Trans = 'SELECT top 100  * FROM DocumentBillTransaction'
connection =  db.connection().connect()
bill = pd.read_sql(text(d_bill), connection)
trans = pd.read_sql(text(d_Trans), connection)

# bills = bill.iloc[1]
bill.iloc[1]
# bills=bill.fillna('R')

# print(bill.isnull().sum().to_string())

##bill['TaskStageStatus'] = bill['TaskStageStatus'].fillna('ravi')
# bill['DocumentBillID'].describe()


# bill
# Out:
# DocumentBillID                                        2
# MerchantID                                            1
# TenantID                                              1
# WorkOrderID                                           1
# WorkOrderKey       756664eb-3ca8-4b83-b47c-eda033db82e6
#                                    ...
# TaskStageStatus                                    None
# TaskStageType                                      None
# TaskAssignedTo                                     None
# TaskAssignedBy                                     None
# AppInstance                               BILLPAY 1.0.0
# Name: 1, Length: 106, dtype: object

# %%
from sqlalchemy import create_engine ,text
import pandas as pd


# Define your connection string
connection_string = "mssql+pyodbc://GoveAdmin:gove321admin+@192.129.253.66:1433/Alita-Penske-Document-Dms_20240610?driver=SQL+Server"

# Create an engine object
engine = create_engine(connection_string)

# Test the connection
connection = engine.connect()
result = connection.execute(text("SELECT top 2 * From DocumentBill")).fetchall()

print(type(result))

df = pd.DataFrame(result)
print(df.nunique().to_string())
# df.columns('DocumentBillID')
# Out:
# <class 'list'>
# DocumentBillID                  2
# MerchantID                      1
# TenantID                        1
# WorkOrderID                     1
# WorkOrderKey                    1
# DocumentID                      0
# DocumentTemplateID              2
# DocumentBillTypeID              2
# DocumentKey                     0
# AccountNumber                   1
# PlateCountry                    1
# PlateState                      1
# PlateNumber                     2
# BillNumber                      2
# BillDate                        2
# BillTitle                       2
# MailedDate                      0
# DueDate                         2
# BillToAddress                   0
# BillFromAddress                 0
# CheckMailingAddress             1
# IsMandatoryCountryAppearence    1
# BillType                        2
# NoticeType                      1
# VendorCode                      2
# VendorName                      1
# TotalTransactionAmount          2
# ...
