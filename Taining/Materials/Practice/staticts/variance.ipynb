# %%
import statistics as s


# print(s.pvariance([2,2,4,4]))

print('MEAN :',s.fmean([1,3,4,5,6]))
print('MEADIAN :',s.median([1,3,4,5,6,7]))
print('MODE :',s.mode([1,3,4,5,6,6]))
# Out:
# MEAN : 3.8
# MEADIAN : 4.5
# MODE : 6
