# %%
'''
Given a string s, find the length of the longest substring without duplicate characters.

 

Example 1:

Input: s = "abcabcbb"
Output: 3
Explanation: The answer is "abc", with the length of 3. Note that "bca" and "cab" are also correct answers.'''


class Solution(object):
    def lengthOfLongestSubstring(self, s):
        """
        :type s: str
        :rtype: int
        """
        max_length = 0
        
        for i in range(len(s)):
            
            seen = []
            
            for j in range(i, len(s)):
                if s[j] in seen:
                    print(s[j])
                    break                
                seen.append(s[j])                

                max_length = max(max_length, j - i + 1)
        
        return max_length


sol = Solution()

print(sol.lengthOfLongestSubstring("awolawolawolbabcabcbb"))
# Out:
# a
# w
# o
# l
# a
# w
# o
# l
# a
# b
# b
# b
# b
# a
# b
# c
# b
# b
# b
# b
# 5

# %%
class Solution(object):
    def lengthOfLongestSubstring(self, s):

        max_length = 0
        
        for i in range(len(s)):
            
            seen = []
            print("\nStart i =", i)
            
            for j in range(i, len(s)):
                
                print(" checking:", s[j])
                
                if s[j] in seen:
                    print("  duplicate found:", s[j])
                    break
                
                seen.append(s[j])
                print("  seen:", seen)
                
                max_length = max(max_length, j - i + 1)
                print("  max_length:", max_length)
        
        return max_length


sol = Solution()

print("\nFinal Answer:",
      sol.lengthOfLongestSubstring("awolawolawolbabcabcbb"))
# Out:
# Start i = 0
#  checking: a
#   seen: ['a']
#   max_length: 1
#  checking: w
#   seen: ['a', 'w']
#   max_length: 2
#  checking: o
#   seen: ['a', 'w', 'o']
#   max_length: 3
#  checking: l
#   seen: ['a', 'w', 'o', 'l']
#   max_length: 4
#  checking: a
#   duplicate found: a
#
# Start i = 1
#  checking: w
#   seen: ['w']
#   max_length: 4
#  checking: o
#   seen: ['w', 'o']
#   max_length: 4
#  checking: l
#   seen: ['w', 'o', 'l']
#   max_length: 4
#  checking: a
#   seen: ['w', 'o', 'l', 'a']
#   max_length: 4
#  checking: w
#   duplicate found: w
#
# Start i = 2
#  checking: o
#   seen: ['o']
#   max_length: 4
#  checking: l
#   seen: ['o', 'l']
#   max_length: 4
#  checking: a
#   seen: ['o', 'l', 'a']
#   max_length: 4
#  checking: w
#   seen: ['o', 'l', 'a', 'w']
#   max_length: 4
#  checking: o
#   duplicate found: o
#
# Start i = 3
#  checking: l
#   seen: ['l']
#   max_length: 4
#  checking: a
#   seen: ['l', 'a']
#   max_length: 4
#  checking: w
#   seen: ['l', 'a', 'w']
#   max_length: 4
#  checking: o
#   seen: ['l', 'a', 'w', 'o']
#   max_length: 4
#  checking: l
#   duplicate found: l
#
# Start i = 4
#  checking: a
#   seen: ['a']
#   max_length: 4
#  checking: w
#   seen: ['a', 'w']
#   max_length: 4
#  checking: o
#   seen: ['a', 'w', 'o']
#   max_length: 4
#  checking: l
#   seen: ['a', 'w', 'o', 'l']
#   max_length: 4
#  checking: a
#   duplicate found: a
#
# Start i = 5
#  checking: w
#   seen: ['w']
#   max_length: 4
#  checking: o
#   seen: ['w', 'o']
#   max_length: 4
#  checking: l
#   seen: ['w', 'o', 'l']
#   max_length: 4
#  checking: a
#   seen: ['w', 'o', 'l', 'a']
#   max_length: 4
#  checking: w
#   duplicate found: w
#
# Start i = 6
#  checking: o
#   seen: ['o']
#   max_length: 4
#  checking: l
#   seen: ['o', 'l']
#   max_length: 4
#  checking: a
#   seen: ['o', 'l', 'a']
#   max_length: 4
#  checking: w
#   seen: ['o', 'l', 'a', 'w']
#   max_length: 4
#  checking: o
#   duplicate found: o
#
# Start i = 7
#  checking: l
#   seen: ['l']
#   max_length: 4
#  checking: a
#   seen: ['l', 'a']
#   max_length: 4
#  checking: w
#   seen: ['l', 'a', 'w']
#   max_length: 4
#  checking: o
#   seen: ['l', 'a', 'w', 'o']
#   max_length: 4
#  checking: l
#   duplicate found: l
#
# Start i = 8
#  checking: a
#   seen: ['a']
#   max_length: 4
#  checking: w
#   seen: ['a', 'w']
#   max_length: 4
#  checking: o
#   seen: ['a', 'w', 'o']
#   max_length: 4
#  checking: l
#   seen: ['a', 'w', 'o', 'l']
#   max_length: 4
#  checking: b
#   seen: ['a', 'w', 'o', 'l', 'b']
#   max_length: 5
#  checking: a
#   duplicate found: a
#
# Start i = 9
#  checking: w
#   seen: ['w']
#   max_length: 5
#  checking: o
#   seen: ['w', 'o']
#   max_length: 5
#  checking: l
#   seen: ['w', 'o', 'l']
#   max_length: 5
#  checking: b
#   seen: ['w', 'o', 'l', 'b']
#   max_length: 5
#  checking: a
#   seen: ['w', 'o', 'l', 'b', 'a']
#   max_length: 5
#  checking: b
#   duplicate found: b
#
# Start i = 10
#  checking: o
#   seen: ['o']
#   max_length: 5
#  checking: l
#   seen: ['o', 'l']
#   max_length: 5
#  checking: b
#   seen: ['o', 'l', 'b']
#   max_length: 5
#  checking: a
#   seen: ['o', 'l', 'b', 'a']
#   max_length: 5
#  checking: b
#   duplicate found: b
#
# Start i = 11
#  checking: l
#   seen: ['l']
#   max_length: 5
#  checking: b
#   seen: ['l', 'b']
#   max_length: 5
#  checking: a
#   seen: ['l', 'b', 'a']
#   max_length: 5
#  checking: b
#   duplicate found: b
#
# Start i = 12
#  checking: b
#   seen: ['b']
#   max_length: 5
#  checking: a
#   seen: ['b', 'a']
#   max_length: 5
#  checking: b
#   duplicate found: b
#
# Start i = 13
#  checking: a
#   seen: ['a']
#   max_length: 5
#  checking: b
#   seen: ['a', 'b']
#   max_length: 5
#  checking: c
#   seen: ['a', 'b', 'c']
#   max_length: 5
#  checking: a
#   duplicate found: a
#
# Start i = 14
#  checking: b
#   seen: ['b']
#   max_length: 5
#  checking: c
#   seen: ['b', 'c']
#   max_length: 5
#  checking: a
#   seen: ['b', 'c', 'a']
#   max_length: 5
#  checking: b
#   duplicate found: b
#
# Start i = 15
#  checking: c
#   seen: ['c']
#   max_length: 5
#  checking: a
#   seen: ['c', 'a']
#   max_length: 5
#  checking: b
#   seen: ['c', 'a', 'b']
#   max_length: 5
#  checking: c
#   duplicate found: c
#
# Start i = 16
#  checking: a
#   seen: ['a']
#   max_length: 5
#  checking: b
#   seen: ['a', 'b']
#   max_length: 5
#  checking: c
#   seen: ['a', 'b', 'c']
#   max_length: 5
#  checking: b
#   duplicate found: b
#
# Start i = 17
#  checking: b
#   seen: ['b']
#   max_length: 5
#  checking: c
#   seen: ['b', 'c']
#   max_length: 5
#  checking: b
#   duplicate found: b
#
# Start i = 18
#  checking: c
#   seen: ['c']
#   max_length: 5
#  checking: b
#   seen: ['c', 'b']
#   max_length: 5
#  checking: b
#   duplicate found: b
#
# Start i = 19
#  checking: b
#   seen: ['b']
#   max_length: 5
#  checking: b
#   duplicate found: b
#
# Start i = 20
#  checking: b
#   seen: ['b']
#   max_length: 5
#
# Final Answer: 5
